# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('iris.csv',header=None)
data.columns=['sepal length','sepal width','petal length','petal width','class']

# %%
data.head()
# Out:
#    sepal length  sepal width  petal length  petal width   class
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data.sample(10)
# Out:
#      sepal length  sepal width  petal length  petal width       class
# 109           7.2          3.6           6.1          2.5   virginica
# 80            5.5          2.4           3.8          1.1  versicolor
# 41            4.5          2.3           1.3          0.3      setosa
# 18            5.7          3.8           1.7          0.3      setosa
# 133           6.3          2.8           5.1          1.5   virginica
# 69            5.6          2.5           3.9          1.1  versicolor
# 125           7.2          3.2           6.0          1.8   virginica
# 130           7.4          2.8           6.1          1.9   virginica
# 64            5.6          2.9           3.6          1.3  versicolor
# 10            5.4          3.7           1.5          0.2      setosa

# %%
data.columns
# Out:
# Index(['sepal length', 'sepal width', 'petal length', 'petal width', 'class'], dtype='object')

# %%
data.shape
# Out:
# (150, 5)

# %%
print(data)
# Out:
#      sepal length  sepal width  petal length  petal width      class
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
print(data[10:21])
# Out:
#     sepal length  sepal width  petal length  petal width   class
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# 13           4.3          3.0           1.1          0.1  setosa
# 14           5.8          4.0           1.2          0.2  setosa
# 15           5.7          4.4           1.5          0.4  setosa
# 16           5.4          3.9           1.3          0.4  setosa
# 17           5.1          3.5           1.4          0.3  setosa
# 18           5.7          3.8           1.7          0.3  setosa
# 19           5.1          3.8           1.5          0.3  setosa
# 20           5.4          3.4           1.7          0.2  setosa

# %%
specific_data=data[['class']]
print(specific_data.head(10))
# Out:
#     class
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa
# 5  setosa
# 6  setosa
# 7  setosa
# 8  setosa
# 9  setosa

# %%
data.iloc[5]
# Out:
# sepal length       5.4
# sepal width        3.9
# petal length       1.7
# petal width        0.4
# class           setosa
# Name: 5, dtype: object

# %%
data.loc[data['class']=='setosa']
# Out:
#     sepal length  sepal width  petal length  petal width   class
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
data['class'].value_counts()
# Out:
# virginica     50
# setosa        50
# versicolor    50
# Name: class, dtype: int64

# %%
data.describe(include='all')
# Out:
#         sepal length  sepal width  petal length  petal width      class
# count     150.000000   150.000000    150.000000   150.000000        150
# unique           NaN          NaN           NaN          NaN          3
# top              NaN          NaN           NaN          NaN  virginica
# freq             NaN          NaN           NaN          NaN         50
# mean        5.843333     3.054000      3.758667     1.198667        NaN
# std         0.828066     0.433594      1.764420     0.763161        NaN
# min         4.300000     2.000000      1.000000     0.100000        NaN
# 25%         5.100000     2.800000      1.600000     0.300000        NaN
# 50%         5.800000     3.000000      4.350000     1.300000        NaN
# 75%         6.400000     3.300000      5.100000     1.800000        NaN
# max         7.900000     4.400000      6.900000     2.500000        NaN

# %%
from pandas.api.types import is_numeric_dtype
for col in data.columns:
    if is_numeric_dtype(data[col]):
        print('%s:'%(col))
        print('\t Mean is %.2f' % data[col].mean())
        print('\t Standard deviation=%.2f'% data[col].std())
        print('\t Minimum=%s.2f'% data[col].min())
        print('\t Maximum=%s.2f'% data[col].max())
# Out:
# sepal length:
# 	 Mean is 5.84
# 	 Standard deviation=0.83
# 	 Minimum=4.3.2f
# 	 Maximum=7.9.2f
# sepal width:
# 	 Mean is 3.05
# 	 Standard deviation=0.43
# 	 Minimum=2.0.2f
# 	 Maximum=4.4.2f
# petal length:
# 	 Mean is 3.76
# 	 Standard deviation=1.76
# 	 Minimum=1.0.2f
# 	 Maximum=6.9.2f
# petal width:
# 	 Mean is 1.20
# 	 Standard deviation=0.76
# 	 Minimum=0.1.2f
# 	 Maximum=2.5.2f

# %%
print('COVARIENCE')
data.cov()
# Out:
# COVARIENCE
#               sepal length  sepal width  petal length  petal width
# sepal length      0.685694    -0.039268      1.273682     0.516904
# sepal width      -0.039268     0.188004     -0.321713    -0.117981
# petal length      1.273682    -0.321713      3.113179     1.296387
# petal width       0.516904    -0.117981      1.296387     0.582414

# %%
print('correaltion')
data.corr()
# Out:
# correaltion
#               sepal length  sepal width  petal length  petal width
# sepal length      1.000000    -0.109369      0.871754     0.817954
# sepal width      -0.109369     1.000000     -0.420516    -0.356544
# petal length      0.871754    -0.420516      1.000000     0.962757
# petal width       0.817954    -0.356544      0.962757     1.000000

# %%
data.style
# Out:
# <style  type="text/css" >
# </style><table id="T_43404_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sepal length</th>        <th class="col_heading level0 col1" >sepal width</th>        <th class="col_heading level0 col2" >petal length</th>        <th class="col_heading level0 col3" >petal width</th>        <th class="col_heading level0 col4" >class</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_43404_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_43404_row0_col0" class="data row0 col0" >5.100000</td>
#                         <td id="T_43404_row0_col1" class="data row0 col1" >3.500000</td>
#                         <td id="T_43404_row0_col2" class="data row0 col2" >1.400000</td>
#                         <td id="T_43404_row0_col3" class="data row0 col3" >0.200000</td>
# ...

# %%
data.head(10).style.highlight_max(color='lightgreen',axis=0)
# Out:
# <style  type="text/css" >
# #T_1821b_row5_col0,#T_1821b_row5_col1,#T_1821b_row5_col2,#T_1821b_row5_col3{
#             background-color:  lightgreen;
#         }</style><table id="T_1821b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sepal length</th>        <th class="col_heading level0 col1" >sepal width</th>        <th class="col_heading level0 col2" >petal length</th>        <th class="col_heading level0 col3" >petal width</th>        <th class="col_heading level0 col4" >class</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1821b_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1821b_row0_col0" class="data row0 col0" >5.100000</td>
#                         <td id="T_1821b_row0_col1" class="data row0 col1" >3.500000</td>
#                         <td id="T_1821b_row0_col2" class="data row0 col2" >1.400000</td>
# ...

# %%
data.head(10).style.highlight_max(color='lightgreen',axis=1)
# Out:
# <style  type="text/css" >
# #T_b7bfb_row0_col0,#T_b7bfb_row1_col0,#T_b7bfb_row2_col0,#T_b7bfb_row3_col0,#T_b7bfb_row4_col0,#T_b7bfb_row5_col0,#T_b7bfb_row6_col0,#T_b7bfb_row7_col0,#T_b7bfb_row8_col0,#T_b7bfb_row9_col0{
#             background-color:  lightgreen;
#         }</style><table id="T_b7bfb_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sepal length</th>        <th class="col_heading level0 col1" >sepal width</th>        <th class="col_heading level0 col2" >petal length</th>        <th class="col_heading level0 col3" >petal width</th>        <th class="col_heading level0 col4" >class</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b7bfb_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b7bfb_row0_col0" class="data row0 col0" >5.100000</td>
#                         <td id="T_b7bfb_row0_col1" class="data row0 col1" >3.500000</td>
# ...

# %%
data.head(10).style.highlight_max(color='lightgreen',axis=None)
# Out:
# <style  type="text/css" >
# #T_b3ed6_row5_col0{
#             background-color:  lightgreen;
#         }</style><table id="T_b3ed6_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sepal length</th>        <th class="col_heading level0 col1" >sepal width</th>        <th class="col_heading level0 col2" >petal length</th>        <th class="col_heading level0 col3" >petal width</th>        <th class="col_heading level0 col4" >class</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b3ed6_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b3ed6_row0_col0" class="data row0 col0" >5.100000</td>
#                         <td id="T_b3ed6_row0_col1" class="data row0 col1" >3.500000</td>
#                         <td id="T_b3ed6_row0_col2" class="data row0 col2" >1.400000</td>
#                         <td id="T_b3ed6_row0_col3" class="data row0 col3" >0.200000</td>
# ...

# %%
data.isnull()
# Out:
#      sepal length  sepal width  petal length  petal width  class
# 0           False        False         False        False  False
# 1           False        False         False        False  False
# 2           False        False         False        False  False
# 3           False        False         False        False  False
# 4           False        False         False        False  False
# ..            ...          ...           ...          ...    ...
# 145         False        False         False        False  False
# 146         False        False         False        False  False
# 147         False        False         False        False  False
# 148         False        False         False        False  False
# 149         False        False         False        False  False
#
# [150 rows x 5 columns]

# %%
# %matplotlib inline
data['sepal length'].hist(bins=8)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,7))
x=data['sepal width']
plt.hist(x,bins=10,color='green')
plt.title('sepal width in cm')
plt.xlabel('seple_width_cm')
plt.ylabel('counts')
plt.show()

# %%
data.boxplot()
# Out:
# <AxesSubplot:>

# %%
data.plot(kind='scatter',x='sepal length',y='sepal width')
plt.show()

# %%
import seaborn as sns
sns.jointplot(x='sepal length',y='sepal width',data=data,size=5)
plt.show()
# Out:
# c:\python38\lib\site-packages\seaborn\axisgrid.py:2073: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
KS={'color':['red','blue','green']}
sns.FacetGrid(data,hue_kws=KS,hue='class',size=5)\
.map(plt.scatter,'sepal length','sepal width')\
.add_legend()
plt.show()
# Out:
# c:\python38\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
data.isnull().sum()
# Out:
# sepal length    0
# sepal width     0
# petal length    0
# petal width     0
# class           0
# dtype: int64

# %%
data['class'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
num = LabelEncoder()
data['class']=num.fit_transform(data['class'].astype('str'))

# %%
data['class'].dtype
# Out:
# dtype('int32')

# %%
data['class'].unique()
# Out:
# array([0, 1, 2])

# %%
# Train test split
X = data.drop('class',axis=1)
y = data['class']

# %%
X
# Out:
#      sepal length  sepal width  petal length  petal width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: class, Length: 150, dtype: int32

# %%
import numpy as np
np.random.seed(101)
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3)

# %%
X_test
# Out:
#      sepal length  sepal width  petal length  petal width
# 33            5.5          4.2           1.4          0.2
# 16            5.4          3.9           1.3          0.4
# 43            5.0          3.5           1.6          0.6
# 129           7.2          3.0           5.8          1.6
# 50            7.0          3.2           4.7          1.4
# 123           6.3          2.7           4.9          1.8
# 68            6.2          2.2           4.5          1.5
# 53            5.5          2.3           4.0          1.3
# 146           6.3          2.5           5.0          1.9
# 1             4.9          3.0           1.4          0.2
# 147           6.5          3.0           5.2          2.0
# 32            5.2          4.1           1.5          0.1
# 31            5.4          3.4           1.5          0.4
# 122           7.7          2.8           6.7          2.0
# 127           6.1          3.0           4.9          1.8
# ...

# %%
#baseline model
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression()
log_reg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix
y_preds = log_reg.predict(X_test)
accuracy_score(y_test,y_preds)
# Out:
# 0.9777777777777777

# %%
print(classification_report(y_test,y_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       1.00      0.95      0.97        20
#            2       0.92      1.00      0.96        12
#
#     accuracy                           0.98        45
#    macro avg       0.97      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45

# %%
con_mat = confusion_matrix(y_test,y_preds)

# %%
sns.heatmap(con_mat,annot = True)
# Out:
# <AxesSubplot:>
